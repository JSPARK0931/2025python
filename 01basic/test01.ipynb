# %%
print("Hello Python")
# Out:
# Hello Python

# %%
# !python --version
# Out:
# Python 3.13.9

# %%
age = 20
print(age)
# Out:
# 20

# %%
print(f'테스트 = {age}')
# Out:
# 테스트 = 20

# %%
print(f'당산의 나이는 {age}살입니다.')
# Out:
# 당산의 나이는 20살입니다.
