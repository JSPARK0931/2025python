# %% [markdown]
# ### 제목
# **test**
# test1
#
#  - 데이터 수직
#  - 데이터 전처리
#     - 결측치 처리
#     - 이상치
#
# 1. 데이터 불러오기
# 1. 모델학습
# 1. 결과평가
#
# `print("hello python")`
#
# ```python
# print("hello python")
# df=pd.read_csv("test.csv")
# ```
#
# |컬럼|설명|
# |----|----|
# |X|입력|
#
# 구글링크 : [구글](http://www.google.com)
#
# ![이미지](이미지경로)
#
# ---
# 구분선
#
# - [x] 데이터로드
# - [ ] 테스트
# - [ ] 결과시각화

# %%
print("test")
# Out:
# test

# %%
age = 20
type(age)
print(type(age))
type(10)
print(type(0.3))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = int (input("정수:"))
b = int (input("정수:"))
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = int (input("정수:"))
#       2 b = int (input("정수:"))
#       3 print(a+b)
#
# ValueError: invalid literal for int() with base 10: '1.3'

# %%
c = float(input('시간 입력 :'))
d = c * 60
print(f'{d}초입니다.')
# Out:
# 120.0초입니다.

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10,20,25,30]
# plt.plot(x,y)
plt.bar(x,y)
#plt.barh(x,y)
plt.show()

# %%
s = [1,2,3,4,5]
score = [60,65,70,85,100]

plt.scatter(s,score)
plt.xlabel("study")
plt.ylabel("score")
plt.title("study time vs score")
plt.show()

# %%
import random
r = random.randint(1,10)
print(r)
answer = int (input("숫자를 맞춰보세요 : "))
print(f'{r == answer} 선택한수는 {answer}이고 답은 {r}입니다.')
# Out:
# 8
# False 선택한수는 5이고 답은 8입니다.

# %%
import random
text = ['서울', '부산', '대구', '대전','제주']
# print(text[0])
# c = random.randint(0,4)
c = random.randint(0,len(text)- 1)
print(text[c])
# Out:
# 부산

# %%
### range(start stop, step)

# %% [markdown]
# ### range(start stop, step)

# %%
print(range(5))


# for i in range(1,10,3):
#     print(i)

for i in (range(0,10)):
    print(i)
    print("hi!!!")
# Out:
# range(0, 5)
# 0
# hi!!!
# 1
# hi!!!
# 2
# hi!!!
# 3
# hi!!!
# 4
# hi!!!
# 5
# hi!!!
# 6
# hi!!!
# 7
# hi!!!
# 8
# hi!!!
# 9
# hi!!!

# %%
for i in range(5):
    print(text[i])
# Out:
# 서울
# 부산
# 대구
# 대전
# 제주

# %%
import random
numbers = list(range(1,46))
# print(numbers)
lotto = random.sample(numbers,6)
lotto.sort()
print(lotto)
# Out:
# [19, 20, 27, 30, 33, 35]
